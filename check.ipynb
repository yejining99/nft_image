# %%
import pandas as pd
import numpy as np
from scipy.sparse import load_npz

import time 
import os
import random
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
from urllib import request
import sys
from tqdm import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/yejining/Desktop/graduate school/bithumb/check.ipynb 셀 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yejining/Desktop/graduate%20school/bithumb/check.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/yejining/Desktop/graduate%20school/bithumb/check.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/Users/yejining/Desktop/graduate%20school/bithumb/check.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from scipy.sparse import load_npz
#
# ModuleNotFoundError: No module named 'pandas'

# %%
combined = pd.read_csv('data/combined.csv')
# make the code for visulaizatin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yejining/Desktop/graduate school/bithumb/check.ipynb 셀 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/yejining/Desktop/graduate%20school/bithumb/check.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> combined = pd.read_csv('data/combined.csv')
#
# NameError: name 'pd' is not defined

# %%
df = combined[['to','tokenSymbol']]

# %%
a = df.groupby('to').agg(['nunique']).value_counts()
a
# Out:
# (tokenSymbol, nunique)
# 1                         25710
# 2                          3212
# 3                           664
# 4                           145
# 5                            31
# dtype: int64

# %%
b = df.groupby('to').agg(['nunique']).value_counts(normalize=True)
b
# Out:
# (tokenSymbol, nunique)
# 1                         0.863853
# 2                         0.107923
# 3                         0.022310
# 4                         0.004872
# 5                         0.001042
# dtype: float64

# %%
c = df.groupby('to')['tokenSymbol'].unique()
c = pd.DataFrame(c.value_counts())

# %%
c

# %%
c = b.value_counts()
c = pd.DataFrame(c)

# %%
d = b.tolist()

# %%
d = list(map(list,d))

# %%
d = list(map(sorted,d))

# %%
e = list(map(str,d))

# %%
d = pd.DataFrame(e)

# %%
d.value_counts()
# Out:
# ['COOL']                                    6091
# ['DOODLE']                                  5347
# ['AZUKI']                                   4859
# ['⚇']                                       4818
# ['BAYC']                                    4595
# ['AZUKI', 'DOODLE']                          552
# ['COOL', 'DOODLE']                           523
# ['BAYC', '⚇']                                328
# ['COOL', '⚇']                                308
# ['AZUKI', 'COOL']                            306
# ['BAYC', 'DOODLE']                           288
# ['DOODLE', '⚇']                              248
# ['AZUKI', 'BAYC']                            244
# ['BAYC', 'COOL']                             241
# ['AZUKI', '⚇']                               174
# ['AZUKI', 'COOL', 'DOODLE']                  141
# ['AZUKI', 'BAYC', 'DOODLE']                  101
# ['COOL', 'DOODLE', '⚇']                       79
# ['BAYC', 'COOL', 'DOODLE']                    66
# ['BAYC', 'DOODLE', '⚇']                       59
# ['AZUKI', 'DOODLE', '⚇']                      47
# ['AZUKI', 'BAYC', 'COOL']                     47
# ['BAYC', 'COOL', '⚇']                         47
# ['AZUKI', 'BAYC', '⚇']                        39
# ['AZUKI', 'COOL', '⚇']                        38
# ['AZUKI', 'COOL', 'DOODLE', '⚇']              38
# ['BAYC', 'COOL', 'DOODLE', '⚇']               37
# ['AZUKI', 'BAYC', 'DOODLE', '⚇']              34
# ['AZUKI', 'BAYC', 'COOL', 'DOODLE', '⚇']      31
# ['AZUKI', 'BAYC', 'COOL', 'DOODLE']           21
# ['AZUKI', 'BAYC', 'COOL', '⚇']                15
# dtype: int64

# %%
a = df.groupby('to').agg(['nunique']).value_counts()

# %%
a
# Out:
# (tokenSymbol, nunique)
# 1                         25710
# 2                          3212
# 3                           664
# 4                           145
# 5                            31
# dtype: int64

# %%
combined.groupby('to')

# %%
AZUKI = combined[combined['tokenSymbol']=='AZUKI']
BAYC = combined[combined['tokenSymbol']=='BAYC']
COOLCATS = combined[combined['tokenSymbol']=='COOL']
DOODLES = combined[combined['tokenSymbol']=='DOODLE']
MEEBITS = combined[combined['tokenSymbol']=='⚇']

# %%
AZUKI_tokenID = sorted(AZUKI['tokenID'].unique())
BAYC_tokenID = sorted(BAYC['tokenID'].unique())
COOLCATS_tokenID = sorted(COOLCATS['tokenID'].unique())
DOODLES_tokenID = sorted(DOODLES['tokenID'].unique())
MEEBITS_tokenID = sorted(MEEBITS['tokenID'].unique())

# %%
complement = list(set(MEEBITS_tokenID) - set(mee_int))
complement
# Out:
# [8195,
#  8204,
#  16397,
#  8212,
#  16406,
#  16409,
#  16411,
#  31,
#  33,
#  16418,
#  16419,
#  16424,
#  49,
#  16433,
#  8243,
#  8244,
#  16436,
#  8249,
#  16441,
#  8255,
#  8256,
#  65,
#  8258,
#  74,
#  16458,
#  8269,
#  16465,
#  8278,
#  16471,
#  8281,
#  110,
#  16494,
#  16501,
#  119,
#  120,
#  123,
#  16510,
#  131,
#  134,
#  8326,
#  16519,
#  147,
#  148,
#  8343,
#  152,
#  156,
#  16541,
#  161,
#  165,
#  8365,
#  16561,
#  16562,
#  16571,
#  8380,
#  198,
#  16582,
#  16585,
#  16586,
#  205,
#  212,
#  213,
#  16602,
#  8412,
#  8414,
#  225,
#  16613,
#  16614,
#  8425,
#  16624,
#  16626,
#  243,
#  8438,
#  8439,
#  248,
#  16651,
#  16660,
#  16662,
#  8475,
#  284,
#  285,
#  8481,
#  295,
#  8490,
#  16682,
#  302,
#  303,
#  305,
#  8498,
#  8502,
#  16695,
#  312,
#  8514,
#  16706,
#  8519,
#  16713,
#  331,
#  8524,
#  16719,
#  339,
#  8531,
#  341,
#  8534,
#  16725,
#  16727,
#  16728,
#  347,
#  16733,
#  16734,
#  8543,
#  8544,
#  16736,
#  354,
#  16738,
#  358,
#  362,
#  8560,
#  370,
#  373,
#  16757,
#  16759,
#  8569,
#  8575,
#  16769,
#  16770,
#  16778,
#  398,
#  16783,
#  402,
#  16790,
#  408,
#  409,
#  410,
#  16795,
#  16796,
#  8605,
#  419,
#  8611,
#  8617,
#  429,
#  8623,
#  442,
#  8635,
#  446,
#  16832,
#  452,
#  16837,
#  461,
#  8654,
#  463,
#  16845,
#  16865,
#  16867,
#  16871,
#  16879,
#  8690,
#  16882,
#  8693,
#  8694,
#  505,
#  8697,
#  8700,
#  509,
#  16892,
#  16895,
#  8705,
#  514,
#  8715,
#  16910,
#  16911,
#  8726,
#  16918,
#  8729,
#  8732,
#  544,
#  16930,
#  16933,
#  8743,
#  556,
#  16944,
#  8753,
#  562,
#  8759,
#  16954,
#  571,
#  16962,
#  8772,
#  8773,
#  582,
#  16966,
#  584,
#  586,
#  8778,
#  16974,
#  16977,
#  8787,
#  596,
#  8790,
#  8791,
#  8794,
#  16986,
#  16989,
#  8800,
#  8802,
#  611,
#  16997,
#  8806,
#  17003,
#  620,
#  17004,
#  17007,
#  8822,
#  631,
#  8824,
#  8826,
#  17019,
#  17021,
#  8835,
#  8844,
#  655,
#  659,
#  8852,
#  8858,
#  667,
#  668,
#  8863,
#  17056,
#  674,
#  17058,
#  8870,
#  684,
#  686,
#  8880,
#  17076,
#  8891,
#  707,
#  710,
#  17096,
#  8905,
#  17099,
#  8910,
#  8912,
#  8916,
#  17119,
#  8931,
#  8933,
#  8934,
#  8935,
#  8939,
#  749,
#  750,
#  753,
#  754,
#  17137,
#  8954,
#  17150,
#  8960,
#  8962,
#  17154,
#  17156,
#  8971,
#  17163,
#  781,
#  17168,
#  790,
#  17174,
#  8984,
#  17175,
#  794,
#  798,
#  17186,
#  17188,
#  805,
#  807,
#  9001,
#  9005,
#  815,
#  17200,
#  17201,
#  9011,
#  822,
#  17206,
#  9017,
#  17210,
#  830,
#  17216,
#  9026,
#  17219,
#  9030,
#  17222,
#  17225,
#  842,
#  843,
#  9035,
#  9044,
#  9047,
#  9060,
#  9061,
#  17253,
#  9063,
#  872,
#  17255,
#  874,
#  17259,
#  9078,
#  9088,
#  9089,
#  899,
#  17283,
#  9093,
#  903,
#  909,
#  9103,
#  912,
#  17295,
#  17297,
#  17298,
#  916,
#  9110,
#  9120,
#  17314,
#  936,
#  17321,
#  942,
#  17327,
#  945,
#  946,
#  17329,
#  948,
#  17334,
#  9143,
#  953,
#  17337,
#  17339,
#  956,
#  9149,
#  17345,
#  9161,
#  970,
#  9164,
#  17357,
#  17359,
#  17366,
#  17369,
#  17372,
#  997,
#  1000,
#  9194,
#  17388,
#  1005,
#  1006,
#  9197,
#  17389,
#  1010,
#  9205,
#  17407,
#  17412,
#  1030,
#  17421,
#  9232,
#  1044,
#  9242,
#  9244,
#  17438,
#  9250,
#  17447,
#  1065,
#  17450,
#  17452,
#  1072,
#  9266,
#  1075,
#  9273,
#  17466,
#  17482,
#  17483,
#  1101,
#  1104,
#  1107,
#  9303,
#  9304,
#  9306,
#  17499,
#  9309,
#  17501,
#  1119,
#  17507,
#  9316,
#  17514,
#  1134,
#  1135,
#  9330,
#  17522,
#  17530,
#  9340,
#  17532,
#  9342,
#  17533,
#  17541,
#  9353,
#  1163,
#  1172,
#  17557,
#  1180,
#  9381,
#  9384,
#  17578,
#  1195,
#  9388,
#  17581,
#  9393,
#  1207,
#  9399,
#  1209,
#  9400,
#  17594,
#  17597,
#  9406,
#  1217,
#  17602,
#  17604,
#  1226,
#  1233,
#  9426,
#  9431,
#  1248,
#  9446,
#  17639,
#  9448,
#  9450,
#  1259,
#  17648,
#  1267,
#  9459,
#  17651,
#  1270,
#  9462,
#  1272,
#  9466,
#  1276,
#  9484,
#  17676,
#  17685,
#  17689,
#  1307,
#  1310,
#  17694,
#  9505,
#  17698,
#  1315,
#  9508,
#  9511,
#  9514,
#  1323,
#  17706,
#  17709,
#  1329,
#  17713,
#  17716,
#  17717,
#  1334,
#  17721,
#  1341,
#  1342,
#  17726,
#  9536,
#  9540,
#  1358,
#  9554,
#  9559,
#  9561,
#  1374,
#  1377,
#  1378,
#  1381,
#  17770,
#  9584,
#  17778,
#  1397,
#  17781,
#  17786,
#  17788,
#  9597,
#  17789,
#  1408,
#  1414,
#  17798,
#  17800,
#  9613,
#  1422,
#  1426,
#  9621,
#  9622,
#  17813,
#  1433,
#  17818,
#  17826,
#  1443,
#  9635,
#  9638,
#  17835,
#  17838,
#  1456,
#  9656,
#  17853,
#  1470,
#  1472,
#  17860,
#  9670,
#  1481,
#  1483,
#  9675,
#  17875,
#  9684,
#  17877,
#  17880,
#  1497,
#  17884,
#  9696,
#  17888,
#  9699,
#  9702,
#  1512,
#  17903,
#  9721,
#  1531,
#  9724,
#  1537,
#  1540,
#  9733,
#  1542,
#  1544,
#  9736,
#  1546,
#  9740,
#  17932,
#  17934,
#  1554,
#  17938,
#  1557,
#  9766,
#  9769,
#  17972,
#  1590,
#  17975,
#  1595,
#  9795,
#  1606,
#  17991,
#  9805,
#  1617,
#  1619,
#  1625,
#  1629,
#  9826,
#  1637,
#  9831,
#  18024,
#  9835,
#  18034,
#  1657,
#  9851,
#  18043,
#  9854,
#  1666,
#  9858,
#  9859,
#  18057,
#  9867,
#  1679,
#  1681,
#  9874,
#  1691,
#  9897,
#  18093,
#  1711,
#  18097,
#  9907,
#  1719,
#  18106,
#  9915,
#  9925,
#  9930,
#  1744,
#  18130,
#  18132,
#  1749,
#  9942,
#  1757,
#  18142,
#  9952,
#  9957,
#  18149,
#  1771,
#  9963,
#  18155,
#  1779,
#  18173,
#  9982,
#  1796,
#  1798,
#  1800,
#  1801,
#  1802,
#  9996,
#  18188,
#  1808,
#  10003,
#  1814,
#  10008,
#  10009,
#  10011,
#  10012,
#  18210,
#  18212,
#  10021,
#  1833,
#  1837,
#  18222,
#  18223,
#  1841,
#  1842,
#  18227,
#  10041,
#  1852,
#  1857,
#  10049,
#  18252,
#  18253,
#  10062,
#  18255,
#  10065,
#  18259,
#  10070,
#  18263,
#  10072,
#  10080,
#  10081,
#  1890,
#  1891,
#  10084,
#  18272,
#  18274,
#  18277,
#  18279,
#  18284,
#  10094,
#  18288,
#  10097,
#  18289,
#  18292,
#  10103,
#  10106,
#  10109,
#  18301,
#  10111,
#  1925,
#  10126,
#  18318,
#  10128,
#  1937,
#  1938,
#  18323,
#  18325,
#  10134,
#  10135,
#  18327,
#  18328,
#  1947,
#  1952,
#  18336,
#  18344,
#  18348,
#  10157,
#  1966,
#  1967,
#  18353,
#  18354,
#  18355,
#  18359,
#  10169,
#  10170,
#  1979,
#  10176,
#  10183,
#  1993,
#  10186,
#  10199,
#  2017,
#  2018,
#  2022,
#  10214,
#  10216,
#  10222,
#  18419,
#  2036,
#  10231,
#  18427,
#  18428,
#  10239,
#  10245,
#  2056,
#  2061,
#  2062,
#  10253,
#  10255,
#  10260,
#  10261,
#  18452,
#  18454,
#  10264,
#  2075,
#  2078,
#  18462,
#  18463,
#  18469,
#  2090,
#  2091,
#  10284,
#  2094,
#  10286,
#  18479,
#  2101,
#  18491,
#  2109,
#  10301,
#  18493,
#  18495,
#  10309,
#  2118,
#  10314,
#  2124,
#  2129,
#  2130,
#  10322,
#  10326,
#  10332,
#  10341,
#  18535,
#  2154,
#  2156,
#  10350,
#  2164,
#  2169,
#  2175,
#  2176,
#  18563,
#  10373,
#  18565,
#  18566,
#  2191,
#  10383,
#  18575,
#  2194,
#  2198,
#  10390,
#  10397,
#  10406,
#  2215,
#  18601,
#  2218,
#  10411,
#  18604,
#  10416,
#  10423,
#  2234,
#  2240,
#  10436,
#  2245,
#  2247,
#  2252,
#  10447,
#  10450,
#  2267,
#  10460,
#  10461,
#  2274,
#  10466,
#  2276,
#  2280,
#  18671,
#  10484,
#  18677,
#  2294,
#  10486,
#  10488,
#  18680,
#  10490,
#  2299,
#  18682,
#  10495,
#  2304,
#  2306,
#  2311,
#  10506,
#  2315,
#  10507,
#  10513,
#  10515,
#  18707,
#  18709,
#  10520,
#  18712,
#  18717,
#  10529,
#  2338,
#  18723,
#  2341,
#  2343,
#  10541,
#  2350,
#  2351,
#  2353,
#  10545,
#  18742,
#  10554,
#  2368,
#  10562,
#  10564,
#  10574,
#  18768,
#  10577,
#  2386,
#  10580,
#  2397,
#  10591,
#  18784,
#  10593,
#  10595,
#  18790,
#  2409,
#  10601,
#  18794,
#  18795,
#  18796,
#  2414,
#  18797,
#  2418,
#  18811,
#  18817,
#  18818,
#  2435,
#  2436,
#  18823,
#  2450,
#  18834,
#  18843,
#  2461,
#  10660,
#  2480,
#  18864,
#  10675,
#  10680,
#  10684,
#  10688,
#  2499,
#  18890,
#  10705,
#  18898,
#  2515,
#  18902,
#  2524,
#  2526,
#  2528,
#  10720,
#  2535,
#  18923,
#  2540,
#  10735,
#  2544,
#  2547,
#  18932,
#  2554,
#  10755,
#  18954,
#  10764,
#  10765,
#  18957,
#  2576,
#  10772,
#  2583,
#  2585,
#  18972,
#  18973,
#  2591,
#  2592,
#  10784,
#  10793,
#  10794,
#  2613,
#  10806,
#  2623,
#  10818,
#  19016,
#  2635,
#  2637,
#  2646,
#  19032,
#  19033,
#  10842,
#  10846,
#  2656,
#  2657,
#  10850,
#  2659,
#  19040,
#  19043,
#  2662,
#  2667,
#  2670,
#  19056,
#  19059,
#  10873,
#  10878,
#  10881,
#  19076,
#  10885,
#  19077,
#  10893,
#  10894,
#  19091,
#  19093,
#  19098,
#  2719,
#  19103,
#  19107,
#  2724,
#  2725,
#  10917,
#  2737,
#  2751,
#  10944,
#  10946,
#  19141,
#  10953,
#  10961,
#  19154,
#  10964,
#  19156,
#  19163,
#  10977,
#  2788,
#  2789,
#  2790,
#  2793,
#  2796,
#  2797,
#  10988,
#  2801,
#  2802,
#  10993,
#  19188,
#  10998,
#  19191,
#  2808,
#  2811,
#  2814,
#  11009,
#  11014,
#  2826,
#  19213,
#  19220,
#  19222,
#  11032,
#  19227,
#  19230,
#  19231,
#  11040,
#  11042,
#  19234,
#  19235,
#  19241,
#  2858,
#  11051,
#  19248,
#  2868,
#  2869,
#  19252,
#  2872,
#  11064,
#  2874,
#  11065,
#  11068,
#  11069,
#  19257,
#  2884,
#  11078,
#  2891,
#  19275,
#  19280,
#  2897,
#  19283,
#  2911,
#  2912,
#  11107,
#  11109,
#  11113,
#  2923,
#  2932,
#  2935,
#  2936,
#  ...]

# %%
driver = webdriver.Chrome('./chromedriver')
driver.implicitly_wait(15)
driver.get('https://opensea.io/collection/azuki')

time.sleep(random.uniform(2,4))

for i in tqdm(AZUKI_tokenID[3624:]):
    try:
        time.sleep(random.uniform(2.0,3.0))
        getToken = str(i)
        tokenInput = driver.find_element("xpath", "/html/body/div[1]/div/main/div/div/div/div[5]/div/div[3]/div[1]/div/div/div/div/div[2]/div/span/div/div/div[1]/input")
        tokenInput.send_keys(getToken)
        time.sleep(random.uniform(1,2))
        tokenInput.send_keys(Keys.ENTER)

        clearAll = driver.find_element("xpath", "/html/body/div[1]/div/main/div/div/div/div[5]/div/div[3]/div[3]/div[3]/div[3]/div/div/ul/li[2]/div/button")
        clickClearAll = clearAll.click()
        time.sleep(random.uniform(0.5, 1.0))
        tokenInput.send_keys(Keys.ENTER)

        time.sleep(random.uniform(2.5, 3.0))

        whereImg = driver.find_element("xpath", "/html/body/div[1]/div/main/div/div/div/div[5]/div/div[3]/div[3]/div[3]/div[4]/div[2]/div/div/div/div/article/a/div[1]/div/div/div/span/img")
        imageUrl = whereImg.get_attribute('src')
        request.urlretrieve(imageUrl, "./data/image/AZUKI/"+str(getToken)+".jpg")

        driver.refresh()
        
    except:
        driver.refresh()


driver.close()
# Out:
# /var/folders/g4/2nx009lx1wz8pyphx3cbx0j00000gn/T/ipykernel_99746/1482045355.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
#  15%|██████▏                                 | 180/1174 [30:42<2:49:33, 10.23s/it]
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [11], in <cell line: 7>()
#      13 time.sleep(random.uniform(1,2))
# ---> 14 tokenInput.send_keys(Keys.ENTER)
#      16 clearAll = driver.find_element("xpath", "/html/body/div[1]/div/main/div/div/div/div[5]/div/div[3]/div[3]/div[3]/div[3]/div/div/ul/li[2]/div/button")
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tf/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py:223, in WebElement.send_keys(self, *value)
#     221         value = '\n'.join(remote_files)
# --> 223 self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     224               {'text': "".join(keys_to_typing(value)),
#     225                'value': keys_to_typing(value)})
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tf/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py:396, in WebElement._execute(self, command, params)
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tf/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tf/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=105.0.5195.102)
# Stacktrace:
# 0   chromedriver                        0x0000000102b1da90 chromedriver + 3889808
# 1   chromedriver                        0x0000000102aacb54 chromedriver + 3427156
# 2   chromedriver                        0x000000010279e238 chromedriver + 221752
# 3   chromedriver                        0x0000000102782958 chromedriver + 108888
# 4   chromedriver                        0x000000010278adc8 chromedriver + 142792
# 5   chromedriver                        0x00000001027f8080 chromedriver + 589952
# 6   chromedriver                        0x00000001027c454c chromedriver + 378188
# 7   chromedriver                        0x0000000102af12f8 chromedriver + 3707640
# 8   chromedriver                        0x0000000102af4ea8 chromedriver + 3722920
# 9   chromedriver                        0x0000000102afb3d8 chromedriver + 3748824
# 10  chromedriver                        0x0000000102af59a8 chromedriver + 3725736
# 11  chromedriver                        0x0000000102ad0de8 chromedriver + 3575272
# 12  chromedriver                        0x0000000102b0fd1c chromedriver + 3833116
# 13  chromedriver                        0x0000000102b0fe84 chromedriver + 3833476
# 14  chromedriver                        0x0000000102b24210 chromedriver + 3916304
# 15  libsystem_pthread.dylib             0x0000000180b8026c _pthread_start + 148
# 16  libsystem_pthread.dylib             0x0000000180b7b08c thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [11], in <cell line: 7>()
#      27         driver.refresh()
#      29     except:
# ---> 30         driver.refresh()
#      33 driver.close()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tf/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:673, in WebDriver.refresh(self)
#     664 def refresh(self) -> None:
#     665     """
#     666     Refreshes the current page.
#     667
#    (...)
#     671             driver.refresh()
#     672     """
# --> 673     self.execute(Command.REFRESH)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tf/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tf/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=105.0.5195.102)
# Stacktrace:
# 0   chromedriver                        0x0000000102b1da90 chromedriver + 3889808
# 1   chromedriver                        0x0000000102aacb54 chromedriver + 3427156
# 2   chromedriver                        0x000000010279e238 chromedriver + 221752
# 3   chromedriver                        0x0000000102782958 chromedriver + 108888
# 4   chromedriver                        0x000000010278adc8 chromedriver + 142792
# 5   chromedriver                        0x00000001027f8080 chromedriver + 589952
# 6   chromedriver                        0x00000001027c454c chromedriver + 378188
# 7   chromedriver                        0x0000000102af12f8 chromedriver + 3707640
# 8   chromedriver                        0x0000000102af4ea8 chromedriver + 3722920
# 9   chromedriver                        0x0000000102afb3d8 chromedriver + 3748824
# 10  chromedriver                        0x0000000102af59a8 chromedriver + 3725736
# 11  chromedriver                        0x0000000102ad0de8 chromedriver + 3575272
# 12  chromedriver                        0x0000000102b0fd1c chromedriver + 3833116
# 13  chromedriver                        0x0000000102b0fe84 chromedriver + 3833476
# 14  chromedriver                        0x0000000102b24210 chromedriver + 3916304
# 15  libsystem_pthread.dylib             0x0000000180b8026c _pthread_start + 148
# 16  libsystem_pthread.dylib             0x0000000180b7b08c thread_start + 8
